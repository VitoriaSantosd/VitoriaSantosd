# %% [markdown]
# <a href="https://colab.research.google.com/github/VitoriaSantosd/VitoriaSantosd/blob/main/Relacao_Ongs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
from sklearn.impute import KNNImputer

# %%
pd.set_option('display.max_columns', None)
df = pd.read_csv('RelacaoOngsCarapicuiba.csv')
df.head()
# Out:
#                                        Nome  \
# 0              ASSOCIACAO BENEFICENTE CISNE
# 1     ASSOCIACAO BENEFICENTE DE CARAPICUIBA
# 2     ASSOCIACAO BENEFICENTE DE CARAPICUIBA
# 3    ASSOCIACAO BENEFICIENTE DE CARAPICUIBA
# 4  ASSOCIACAO CULTURAL E COMUNITARIA ZAGAIA
#
#                         Nome Fantasia         Categoria  \
# 0                     INSTITUTO CISNE          EDUCACAO
# 1                     CASA DA CRIANCA  DIREITOS HUMANOS
# 2                     CASA DA CRIANCA          EDUCACAO
# 3                     CASA DA CRIANCA   DESENVOLVIMENTO
# 4  ASS.BRAS DESENVOLVIMENTO DA CIDADE  DIREITOS HUMANOS
#
#                              EndereCo            Bairro      CEP  \
# 0               AV. SAO CAMILO - 3330  CHACARA SAO JOAO  6345410
# 1           AVENIDA MARIA HELENA - 36            CENTRO  6320070
# 2           AVENIDA MARIA HELENA - 36            CENTRO  6320070
# 3           AVENIDA MARIA HELENA - 36            CENTRO  6320070
# ...

# %%
df.isnull().sum()
# Out:
# Nome              0
# Nome Fantasia     4
# Categoria         0
# EndereCo          0
# Bairro            0
#                  ..
# Unnamed: 996     30
# Unnamed: 997     30
# Unnamed: 998     30
# Unnamed: 999     30
# Unnamed: 1000    30
# Length: 1001, dtype: int64

# %%
print(df.shape)
# Out:
# (30, 1001)

# %%
set(df['Categoria'])
# Out:
# {'CRIANCAS',
#  'DESENVOLVIMENTO',
#  'DIREITOS HUMANOS',
#  'DIRETOS HUMANOS',
#  'EDUCACAO',
#  'MEIO AMBIENTE',
#  'SAUDE',
#  'TECNOLOGIA',
#  'TRABALHO',
#  'VOLUNTARIADO'}

# %%
set(df['Bairro'])
# Out:
# {'ALDEIA',
#  'CENTRO',
#  'CHACARA SAO JOAO',
#  'CIDADE ARISTON',
#  'COHAB II',
#  'JD. DAS BELEZAS',
#  'JD. LEONOR',
#  'JD. LEOPOLDINA',
#  'JD. MARILU',
#  'PQ. JANDAIA',
#  'PQ. SANTA TEREZA',
#  'VILA CALDAS'}

# %%
set(df['Municipio'])
# Out:
# {'CARAPICUIBA - SP'}

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Columns: 1001 entries, Nome to Unnamed: 1000
# dtypes: float64(991), int64(2), object(8)
# memory usage: 234.7+ KB

# %%
df_volu = df[df['Categoria'] == 'VOLUNTARIO']
df_des = df[df['Categoria'] == 'DESNVOLVIMENTO']
df_dhum = df[df['Categoria'] == 'DIREITOS HUMANOS']
df_educ = df[df['Categoria'] == 'EDUCAÇÃO']
df_saud = df[df['Categoria'] == 'SAÚDE']
df_tec = df[df['Categoria'] == 'TECNOLOGIA']
df_mamb = df[df['Categoria'] == 'RMEIO AMBIENTE']
df_trab  = df[df['Categoria'] == 'TRABALHO']

df_concatenar = pd.concat([df_volu, df_des, df_dhum, df_mamb, df_trab, df_educ, df_saud])

set(df_concatenar['Categoria'])
# Out:
# {'DIREITOS HUMANOS', 'TRABALHO'}

# %%
RelacaoOngsCarapicuiba = pd.read_csv('RelacaoOngsCarapicuiba.csv')
RelacaoOngsCarapicuiba.head()
# Out:
#                                        Nome  \
# 0              ASSOCIACAO BENEFICENTE CISNE
# 1     ASSOCIACAO BENEFICENTE DE CARAPICUIBA
# 2     ASSOCIACAO BENEFICENTE DE CARAPICUIBA
# 3    ASSOCIACAO BENEFICIENTE DE CARAPICUIBA
# 4  ASSOCIACAO CULTURAL E COMUNITARIA ZAGAIA
#
#                         Nome Fantasia         Categoria  \
# 0                     INSTITUTO CISNE          EDUCACAO
# 1                     CASA DA CRIANCA  DIREITOS HUMANOS
# 2                     CASA DA CRIANCA          EDUCACAO
# 3                     CASA DA CRIANCA   DESENVOLVIMENTO
# 4  ASS.BRAS DESENVOLVIMENTO DA CIDADE  DIREITOS HUMANOS
#
#                              EndereCo            Bairro      CEP  \
# 0               AV. SAO CAMILO - 3330  CHACARA SAO JOAO  6345410
# 1           AVENIDA MARIA HELENA - 36            CENTRO  6320070
# 2           AVENIDA MARIA HELENA - 36            CENTRO  6320070
# 3           AVENIDA MARIA HELENA - 36            CENTRO  6320070
# ...

# %%
RelacaoOngsCarapicuiba.groupby('Categoria').size().plot(kind='bar', color=sns.color_palette('pastel'))
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.show()

# %%
RelacaoOngsCarapicuiba.groupby('Bairro').size().plot(kind='bar', color=sns.color_palette('pastel'))
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.show()
